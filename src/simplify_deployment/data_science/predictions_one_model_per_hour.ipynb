# %%
import pandas as pd
from simplify_deployment.organism import Organism
import plotly.express as px
from sklearn.linear_model import LinearRegression
from pathlib import Path

# %%
prediction_list = []
folder = Path("/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/folds")
for fold in range(12):
    # Raw
    X_train_raw = pd.read_parquet(folder/f"X_train_fold_{fold}.parquet")
    X_test_raw = pd.read_parquet(folder/f"X_test_fold_{fold}.parquet")
    y_train_raw = pd.read_parquet(folder/f"y_train_fold_{fold}.parquet")
    y_test_raw = pd.read_parquet(folder/f"y_test_fold_{fold}.parquet")

    # Data for model
    org = Organism.from_yaml(
        path_config="/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/lag_25_s1_config.yaml",
        path_genome=f"/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/best_genome/lag_25_s1_50_gen_fold_{fold}_best_genome.yaml"
    )
    y_train, X_train = org.create_y_X(
        y_train_raw,
        X_train_raw,
    )
    y_test, X_test = org.create_y_X(
        y_test_raw,
        X_test_raw,
    )

    for hour in range(24):
        X_train_hour_n = X_train.loc[X_train.index.hour == hour,:]
        y_train_hour_n = y_train.loc[y_train.index.hour == hour]

        X_test_hour_n = X_test.loc[X_test.index.hour == hour,:]
        y_test_hour_n = y_test.loc[y_test.index.hour == hour]

        model = LinearRegression()
        model.fit(X_train_hour_n, y_train_hour_n)
        prediction_list.append(
            pd.DataFrame(
                    {
                        "y_pred_one_model_per_hour": model.predict(X_test_hour_n),
                    },
                    index = X_test_hour_n.index,
            )
        )
        print(f"Fold {fold} hour {hour} done.")
# Out:
# Fold 0 hour 0 done.
# Fold 0 hour 1 done.
# Fold 0 hour 2 done.
# Fold 0 hour 3 done.
# Fold 0 hour 4 done.
# Fold 0 hour 5 done.
# Fold 0 hour 6 done.
# Fold 0 hour 7 done.
# Fold 0 hour 8 done.
# Fold 0 hour 9 done.
# Fold 0 hour 10 done.
# Fold 0 hour 11 done.
# Fold 0 hour 12 done.
# Fold 0 hour 13 done.
# Fold 0 hour 14 done.
# Fold 0 hour 15 done.
# Fold 0 hour 16 done.
# Fold 0 hour 17 done.
# Fold 0 hour 18 done.
# Fold 0 hour 19 done.
# Fold 0 hour 20 done.
# Fold 0 hour 21 done.
# Fold 0 hour 22 done.
# Fold 0 hour 23 done.
# Fold 1 hour 0 done.
# Fold 1 hour 1 done.
# Fold 1 hour 2 done.
# Fold 1 hour 3 done.
# Fold 1 hour 4 done.
# Fold 1 hour 5 done.
# Fold 1 hour 6 done.
# Fold 1 hour 7 done.
# Fold 1 hour 8 done.
# Fold 1 hour 9 done.
# Fold 1 hour 10 done.
# Fold 1 hour 11 done.
# Fold 1 hour 12 done.
# Fold 1 hour 13 done.
# Fold 1 hour 14 done.
# Fold 1 hour 15 done.
# Fold 1 hour 16 done.
# Fold 1 hour 17 done.
# Fold 1 hour 18 done.
# Fold 1 hour 19 done.
# Fold 1 hour 20 done.
# Fold 1 hour 21 done.
# Fold 1 hour 22 done.
# Fold 1 hour 23 done.
# Fold 2 hour 0 done.
# Fold 2 hour 1 done.
# Fold 2 hour 2 done.
# Fold 2 hour 3 done.
# Fold 2 hour 4 done.
# Fold 2 hour 5 done.
# Fold 2 hour 6 done.
# Fold 2 hour 7 done.
# Fold 2 hour 8 done.
# Fold 2 hour 9 done.
# Fold 2 hour 10 done.
# Fold 2 hour 11 done.
# Fold 2 hour 12 done.
# Fold 2 hour 13 done.
# Fold 2 hour 14 done.
# Fold 2 hour 15 done.
# Fold 2 hour 16 done.
# Fold 2 hour 17 done.
# Fold 2 hour 18 done.
# Fold 2 hour 19 done.
# Fold 2 hour 20 done.
# Fold 2 hour 21 done.
# Fold 2 hour 22 done.
# Fold 2 hour 23 done.
# Fold 3 hour 0 done.
# Fold 3 hour 1 done.
# Fold 3 hour 2 done.
# Fold 3 hour 3 done.
# Fold 3 hour 4 done.
# Fold 3 hour 5 done.
# Fold 3 hour 6 done.
# Fold 3 hour 7 done.
# Fold 3 hour 8 done.
# Fold 3 hour 9 done.
# Fold 3 hour 10 done.
# Fold 3 hour 11 done.
# Fold 3 hour 12 done.
# Fold 3 hour 13 done.
# Fold 3 hour 14 done.
# Fold 3 hour 15 done.
# Fold 3 hour 16 done.
# Fold 3 hour 17 done.
# Fold 3 hour 18 done.
# Fold 3 hour 19 done.
# Fold 3 hour 20 done.
# Fold 3 hour 21 done.
# Fold 3 hour 22 done.
# Fold 3 hour 23 done.
# Fold 4 hour 0 done.
# Fold 4 hour 1 done.
# Fold 4 hour 2 done.
# Fold 4 hour 3 done.
# Fold 4 hour 4 done.
# Fold 4 hour 5 done.
# Fold 4 hour 6 done.
# Fold 4 hour 7 done.
# Fold 4 hour 8 done.
# Fold 4 hour 9 done.
# Fold 4 hour 10 done.
# Fold 4 hour 11 done.
# Fold 4 hour 12 done.
# Fold 4 hour 13 done.
# Fold 4 hour 14 done.
# Fold 4 hour 15 done.
# Fold 4 hour 16 done.
# Fold 4 hour 17 done.
# Fold 4 hour 18 done.
# Fold 4 hour 19 done.
# Fold 4 hour 20 done.
# Fold 4 hour 21 done.
# Fold 4 hour 22 done.
# Fold 4 hour 23 done.
# Fold 5 hour 0 done.
# Fold 5 hour 1 done.
# Fold 5 hour 2 done.
# Fold 5 hour 3 done.
# Fold 5 hour 4 done.
# Fold 5 hour 5 done.
# Fold 5 hour 6 done.
# Fold 5 hour 7 done.
# Fold 5 hour 8 done.
# Fold 5 hour 9 done.
# Fold 5 hour 10 done.
# Fold 5 hour 11 done.
# Fold 5 hour 12 done.
# Fold 5 hour 13 done.
# Fold 5 hour 14 done.
# Fold 5 hour 15 done.
# Fold 5 hour 16 done.
# Fold 5 hour 17 done.
# Fold 5 hour 18 done.
# Fold 5 hour 19 done.
# Fold 5 hour 20 done.
# Fold 5 hour 21 done.
# Fold 5 hour 22 done.
# Fold 5 hour 23 done.
# Fold 6 hour 0 done.
# Fold 6 hour 1 done.
# Fold 6 hour 2 done.
# Fold 6 hour 3 done.
# Fold 6 hour 4 done.
# Fold 6 hour 5 done.
# Fold 6 hour 6 done.
# Fold 6 hour 7 done.
# Fold 6 hour 8 done.
# Fold 6 hour 9 done.
# Fold 6 hour 10 done.
# Fold 6 hour 11 done.
# Fold 6 hour 12 done.
# Fold 6 hour 13 done.
# Fold 6 hour 14 done.
# Fold 6 hour 15 done.
# Fold 6 hour 16 done.
# Fold 6 hour 17 done.
# Fold 6 hour 18 done.
# Fold 6 hour 19 done.
# Fold 6 hour 20 done.
# Fold 6 hour 21 done.
# Fold 6 hour 22 done.
# Fold 6 hour 23 done.
# Fold 7 hour 0 done.
# Fold 7 hour 1 done.
# Fold 7 hour 2 done.
# Fold 7 hour 3 done.
# Fold 7 hour 4 done.
# Fold 7 hour 5 done.
# Fold 7 hour 6 done.
# Fold 7 hour 7 done.
# Fold 7 hour 8 done.
# Fold 7 hour 9 done.
# Fold 7 hour 10 done.
# Fold 7 hour 11 done.
# Fold 7 hour 12 done.
# Fold 7 hour 13 done.
# Fold 7 hour 14 done.
# Fold 7 hour 15 done.
# Fold 7 hour 16 done.
# Fold 7 hour 17 done.
# Fold 7 hour 18 done.
# Fold 7 hour 19 done.
# Fold 7 hour 20 done.
# Fold 7 hour 21 done.
# Fold 7 hour 22 done.
# Fold 7 hour 23 done.
# Fold 8 hour 0 done.
# Fold 8 hour 1 done.
# Fold 8 hour 2 done.
# Fold 8 hour 3 done.
# Fold 8 hour 4 done.
# Fold 8 hour 5 done.
# Fold 8 hour 6 done.
# Fold 8 hour 7 done.
# Fold 8 hour 8 done.
# Fold 8 hour 9 done.
# Fold 8 hour 10 done.
# Fold 8 hour 11 done.
# Fold 8 hour 12 done.
# Fold 8 hour 13 done.
# Fold 8 hour 14 done.
# Fold 8 hour 15 done.
# Fold 8 hour 16 done.
# Fold 8 hour 17 done.
# Fold 8 hour 18 done.
# Fold 8 hour 19 done.
# Fold 8 hour 20 done.
# Fold 8 hour 21 done.
# Fold 8 hour 22 done.
# Fold 8 hour 23 done.
# Fold 9 hour 0 done.
# Fold 9 hour 1 done.
# Fold 9 hour 2 done.
# Fold 9 hour 3 done.
# Fold 9 hour 4 done.
# Fold 9 hour 5 done.
# Fold 9 hour 6 done.
# Fold 9 hour 7 done.
# Fold 9 hour 8 done.
# Fold 9 hour 9 done.
# Fold 9 hour 10 done.
# Fold 9 hour 11 done.
# Fold 9 hour 12 done.
# Fold 9 hour 13 done.
# Fold 9 hour 14 done.
# Fold 9 hour 15 done.
# Fold 9 hour 16 done.
# Fold 9 hour 17 done.
# Fold 9 hour 18 done.
# Fold 9 hour 19 done.
# Fold 9 hour 20 done.
# Fold 9 hour 21 done.
# Fold 9 hour 22 done.
# Fold 9 hour 23 done.
# Fold 10 hour 0 done.
# Fold 10 hour 1 done.
# Fold 10 hour 2 done.
# Fold 10 hour 3 done.
# Fold 10 hour 4 done.
# Fold 10 hour 5 done.
# Fold 10 hour 6 done.
# Fold 10 hour 7 done.
# Fold 10 hour 8 done.
# Fold 10 hour 9 done.
# Fold 10 hour 10 done.
# Fold 10 hour 11 done.
# Fold 10 hour 12 done.
# Fold 10 hour 13 done.
# Fold 10 hour 14 done.
# Fold 10 hour 15 done.
# Fold 10 hour 16 done.
# Fold 10 hour 17 done.
# Fold 10 hour 18 done.
# Fold 10 hour 19 done.
# Fold 10 hour 20 done.
# Fold 10 hour 21 done.
# Fold 10 hour 22 done.
# Fold 10 hour 23 done.
# Fold 11 hour 0 done.
# Fold 11 hour 1 done.
# Fold 11 hour 2 done.
# Fold 11 hour 3 done.
# Fold 11 hour 4 done.
# Fold 11 hour 5 done.
# Fold 11 hour 6 done.
# Fold 11 hour 7 done.
# Fold 11 hour 8 done.
# Fold 11 hour 9 done.
# Fold 11 hour 10 done.
# Fold 11 hour 11 done.
# Fold 11 hour 12 done.
# Fold 11 hour 13 done.
# Fold 11 hour 14 done.
# Fold 11 hour 15 done.
# Fold 11 hour 16 done.
# Fold 11 hour 17 done.
# Fold 11 hour 18 done.
# Fold 11 hour 19 done.
# Fold 11 hour 20 done.
# Fold 11 hour 21 done.
# Fold 11 hour 22 done.
# Fold 11 hour 23 done.

# %%
prediction = pd.concat(
    prediction_list,
    axis = 0,
)
prediction = prediction.sort_index(ascending = True)
prediction.to_parquet("/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/one_model_per_hour_24_times_more_train.parquet")

# %%
prediction
# Out:
#                            y_pred_one_model_per_hour
# 2022-12-01 21:44:00+00:00                 -64.683115
# 2022-12-01 21:59:00+00:00                 -20.836922
# 2022-12-01 22:14:00+00:00                  77.757653
# 2022-12-01 22:29:00+00:00                  17.545138
# 2022-12-01 22:44:00+00:00                -105.543901
# ...                                              ...
# 2023-10-31 21:29:00+00:00                  94.379971
# 2023-10-31 21:44:00+00:00                  55.298907
# 2023-10-31 21:59:00+00:00                 129.364663
# 2023-10-31 22:14:00+00:00                 118.009876
# 2023-10-31 22:29:00+00:00                 122.554953
#
# [29960 rows x 1 columns]

# %%
X_train
# Out:
#                            siCumulative_lag_25  siCumulative_lag_26  \
# 2019-09-02 21:14:00+00:00               65.124               78.373
# 2019-09-02 21:29:00+00:00              -80.096             -115.483
# 2019-09-02 21:44:00+00:00               53.707               61.370
# 2019-09-02 21:59:00+00:00              265.983              278.118
# 2019-09-02 22:14:00+00:00               70.788               79.115
# ...                                        ...                  ...
# 2023-10-03 21:29:00+00:00              283.273              292.879
# 2023-10-03 21:44:00+00:00               -0.362                4.456
# 2023-10-03 21:59:00+00:00               48.552               14.870
# 2023-10-03 22:14:00+00:00               66.505               65.461
# 2019-09-02 21:44:00+00:00    219.506
# 2019-09-02 21:59:00+00:00    136.241
# 2019-09-02 22:14:00+00:00   -142.903
#                               ...
# 2023-10-03 21:29:00+00:00     -2.456
# 2023-10-03 21:44:00+00:00     86.405
# 2023-10-03 21:59:00+00:00    188.829
# 2023-10-03 22:14:00+00:00    -26.519
# 2023-10-03 22:29:00+00:00     47.031
# Name: siCumulative, Length: 143238, dtype: float64

# %%
pd.read_parquet("/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/one_model_per_hour.parquet")
# Out:
#                            y_pred_one_model_per_hour
# 2022-12-01 21:44:00+00:00                 -64.683115
# 2022-12-01 21:59:00+00:00                 -20.836922
# 2022-12-01 22:14:00+00:00                  77.757653
# 2022-12-01 22:29:00+00:00                  17.545138
# 2022-12-01 22:44:00+00:00                -105.543901
# ...                                              ...
# 2023-10-31 21:29:00+00:00                  94.379971
# 2023-10-31 21:44:00+00:00                  55.298907
# 2023-10-31 21:59:00+00:00                 129.364663
# 2023-10-31 22:14:00+00:00                 118.009876
# 2023-10-31 22:29:00+00:00                 122.554953
#
# [29960 rows x 1 columns]

# %%
fig = px.line(X_train, x = X_train.index, y = ["hour_sin", "hour_cos"])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 fig = px.line(X_train, x = X_train.index, y = ["hour_sin", "hour_cos"])
#       2 fig.show()
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/plotly/express/_chart_types.py:264, in line(data_frame, x, y, line_group, color, line_dash, symbol, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, symbol_sequence, symbol_map, markers, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     216 def line(
#     217     data_frame=None,
#     218     x=None,
#    (...)
#     258     height=None,
#     259 ) -> go.Figure:
#     260     """
#     261     In a 2D line plot, each row of `data_frame` is represented as vertex of
#     262     a polyline mark in 2D space.
#     263     """
# --> 264     return make_figure(args=locals(), constructor=go.Scatter)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/plotly/express/_core.py:2090, in make_figure(args, constructor, trace_patch, layout_patch)
#    2087 layout_patch = layout_patch or {}
#    2088 apply_default_cascade(args)
# -> 2090 args = build_dataframe(args, constructor)
#    2091 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2092     args = process_dataframe_hierarchy(args)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/plotly/express/_core.py:1492, in build_dataframe(args, constructor)
#    1489     args["color"] = None
#    1490 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1492 df_output, wide_id_vars = process_args_into_dataframe(
#    1493     args, wide_mode, var_name, value_name
#    1494 )
#    1496 # now that `df_output` exists and `args` contains only references, we complete
#    1497 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1498 # df_output
#    1500 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/plotly/express/_core.py:1253, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1250         col_name = _check_name_not_reserved(field, reserved_names)
#    1252     if length and len(argument) != length:
# -> 1253         raise ValueError(
#    1254             "All arguments should have the same length. "
#    1255             "The length of argument `%s` is %d, whereas the "
#    1256             "length of  previously-processed arguments %s is %d"
#    1257             % (field, len(argument), str(list(df_output.keys())), length)
#    1258         )
#    1259     df_output[str(col_name)] = to_unindexed_series(argument, str(col_name))
#    1261 # Finally, update argument with column name now that column exists
#
# ValueError: All arguments should have the same length. The length of argument `y` is 2, whereas the length of  previously-processed arguments ['index'] is 143238
