# %%
import pandas as pd
from simplify_deployment.organism import Organism
import plotly.express as px
from sklearn.linear_model import LinearRegression
from pathlib import Path
from tempfile import TemporaryDirectory
from simplify_deployment.data_wrangling import create_target, create_X
from sklearn.model_selection import TimeSeriesSplit
import numpy as np
from sklearn.metrics import mean_squared_error

# %%
def create_datasets(
    path_to_save_folds: Path,
    path_minute_data: Path = Path("/home/thomas/repos/simplify_deployment/data/simplify_1_0/s1_minute_data.parquet"),
    path_qh_data: Path = Path("/home/thomas/repos/simplify_deployment/data/simplify_1_0/s1_quarter_data.parquet"),
    n_splits = 12,
    max_train_size = 16 * 7 * 24 * 60,
    test_size = 4 * 7 * 24 * 60,
):
    X_minute = create_X(
        path_minute_data=path_minute_data,
        path_qh_data=path_qh_data,
    )

    X_minute = X_minute.asfreq("1min").ffill()

    tscv = TimeSeriesSplit(
        n_splits=n_splits,
        max_train_size=max_train_size,
        gap=0,
        test_size=test_size,
    )

    for fold, (train_index, test_index) in enumerate(tscv.split(X_minute)):
        # Train
        X_train = X_minute.iloc[train_index]
        X_train.to_parquet(
            path_to_save_folds / f"X_train_fold_{fold}.parquet",
        )

        y_train = create_target(
            X_train,
        )
        y_train.to_frame().to_parquet(
            path_to_save_folds / f"y_train_fold_{fold}.parquet",
        )

        # Test
        X_test = X_minute.iloc[test_index]
        X_test.to_parquet(
            path_to_save_folds / f"X_test_fold_{fold}.parquet",
        )

        y_test = create_target(
            X_test,
        )
        y_test.to_frame().to_parquet(
            path_to_save_folds / f"y_test_fold_{fold}.parquet",
        )

# %%
rmse_dict = {
    "train_size": [],
    "rmse": [],
}
for train_size in range(7*24*60,16 * 7 * 24 * 60, 7*24*60):
    with TemporaryDirectory() as folder:
        folder = Path(folder)
        create_datasets(
            path_to_save_folds=folder,
            max_train_size=train_size,
        )
        prediction_list = []
        for fold in range(12):
            # Raw
            X_train_raw = pd.read_parquet(folder/f"X_train_fold_{fold}.parquet")
            X_test_raw = pd.read_parquet(folder/f"X_test_fold_{fold}.parquet")
            y_train_raw = pd.read_parquet(folder/f"y_train_fold_{fold}.parquet")
            y_test_raw = pd.read_parquet(folder/f"y_test_fold_{fold}.parquet")

            # Data for model
            org = Organism.from_yaml(
                path_config="/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/lag_25_s1_config.yaml",
                path_genome=f"/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/best_genome/lag_25_s1_50_gen_fold_{fold}_best_genome.yaml"
            )
            y_train, X_train = org.create_y_X(
                y_train_raw,
                X_train_raw,
            )
            y_test, X_test = org.create_y_X(
                y_test_raw,
                X_test_raw,
            )

            for hour in range(24):
                X_train_hour_n = X_train.loc[X_train.index.hour == hour,:]
                y_train_hour_n = y_train.loc[y_train.index.hour == hour]

                X_test_hour_n = X_test.loc[X_test.index.hour == hour,:]
                y_test_hour_n = y_test.loc[y_test.index.hour == hour]

                model = LinearRegression()
                model.fit(X_train_hour_n, y_train_hour_n)
                prediction_list.append(
                    pd.DataFrame(
                            {
                                "y_pred_one_model_per_hour": model.predict(X_test_hour_n),
                                "y_true": y_test_hour_n.values,
                            },
                            index = X_test_hour_n.index,
                    )
                )
                print(f"Fold {fold} hour {hour} train size {train_size} done.")
        prediction = pd.concat(
            prediction_list,
            axis = 0,
        )
        rmse = np.sqrt(mean_squared_error(y_true=prediction["y_true"], y_pred = prediction["y_pred_one_model_per_hour"]))
        print(f"For train size {train_size} the rmse is {rmse} MW.")
        rmse_dict["train_size"].append(train_size)
        rmse_dict["rmse"].append(rmse)

rmse_df = pd.DataFrame(rmse_dict)
print(rmse_df)
# Out:
# Fold 0 hour 0 train size 10080 done.
# Fold 0 hour 1 train size 10080 done.
# Fold 0 hour 2 train size 10080 done.
# Fold 0 hour 3 train size 10080 done.
# Fold 0 hour 4 train size 10080 done.
# Fold 0 hour 5 train size 10080 done.
# Fold 0 hour 6 train size 10080 done.
# Fold 0 hour 7 train size 10080 done.
# Fold 0 hour 8 train size 10080 done.
# Fold 0 hour 9 train size 10080 done.
# Fold 0 hour 10 train size 10080 done.
# Fold 0 hour 11 train size 10080 done.
# Fold 0 hour 12 train size 10080 done.
# Fold 0 hour 13 train size 10080 done.
# Fold 0 hour 14 train size 10080 done.
# Fold 0 hour 15 train size 10080 done.
# Fold 0 hour 16 train size 10080 done.
# Fold 0 hour 17 train size 10080 done.
# Fold 0 hour 18 train size 10080 done.
# Fold 0 hour 19 train size 10080 done.
# Fold 0 hour 20 train size 10080 done.
# Fold 0 hour 21 train size 10080 done.
# Fold 0 hour 22 train size 10080 done.
# Fold 0 hour 23 train size 10080 done.
# Fold 1 hour 0 train size 10080 done.
# Fold 1 hour 1 train size 10080 done.
# Fold 1 hour 2 train size 10080 done.
# Fold 1 hour 3 train size 10080 done.
# Fold 1 hour 4 train size 10080 done.
# Fold 1 hour 5 train size 10080 done.
# Fold 1 hour 6 train size 10080 done.
# Fold 1 hour 7 train size 10080 done.
# Fold 1 hour 8 train size 10080 done.
# Fold 1 hour 9 train size 10080 done.
# Fold 1 hour 10 train size 10080 done.
# Fold 1 hour 11 train size 10080 done.
# Fold 1 hour 12 train size 10080 done.
# Fold 1 hour 13 train size 10080 done.
# Fold 1 hour 14 train size 10080 done.
# Fold 1 hour 15 train size 10080 done.
# Fold 1 hour 16 train size 10080 done.
# Fold 1 hour 17 train size 10080 done.
# Fold 1 hour 18 train size 10080 done.
# Fold 1 hour 19 train size 10080 done.
# Fold 1 hour 20 train size 10080 done.
# Fold 1 hour 21 train size 10080 done.
# Fold 1 hour 22 train size 10080 done.
# Fold 1 hour 23 train size 10080 done.
# Fold 2 hour 0 train size 10080 done.
# Fold 2 hour 1 train size 10080 done.
# Fold 2 hour 2 train size 10080 done.
# Fold 2 hour 3 train size 10080 done.
# Fold 2 hour 4 train size 10080 done.
# Fold 2 hour 5 train size 10080 done.
# Fold 2 hour 6 train size 10080 done.
# Fold 2 hour 7 train size 10080 done.
# Fold 2 hour 8 train size 10080 done.
# Fold 2 hour 9 train size 10080 done.
# Fold 2 hour 10 train size 10080 done.
# Fold 2 hour 11 train size 10080 done.
# Fold 2 hour 12 train size 10080 done.
# Fold 2 hour 13 train size 10080 done.
# Fold 2 hour 14 train size 10080 done.
# Fold 2 hour 15 train size 10080 done.
# Fold 2 hour 16 train size 10080 done.
# Fold 2 hour 17 train size 10080 done.
# Fold 2 hour 18 train size 10080 done.
# Fold 2 hour 19 train size 10080 done.
# Fold 2 hour 20 train size 10080 done.
# Fold 2 hour 21 train size 10080 done.
# Fold 2 hour 22 train size 10080 done.
# Fold 2 hour 23 train size 10080 done.
# Fold 3 hour 0 train size 10080 done.
# Fold 3 hour 1 train size 10080 done.
# Fold 3 hour 2 train size 10080 done.
# Fold 3 hour 3 train size 10080 done.
# Fold 3 hour 4 train size 10080 done.
# Fold 3 hour 5 train size 10080 done.
# Fold 3 hour 6 train size 10080 done.
# Fold 3 hour 7 train size 10080 done.
# Fold 3 hour 8 train size 10080 done.
# Fold 3 hour 9 train size 10080 done.
# Fold 3 hour 10 train size 10080 done.
# Fold 3 hour 11 train size 10080 done.
# Fold 3 hour 12 train size 10080 done.
# Fold 3 hour 13 train size 10080 done.
# Fold 3 hour 14 train size 10080 done.
# Fold 3 hour 15 train size 10080 done.
# Fold 3 hour 16 train size 10080 done.
# Fold 3 hour 17 train size 10080 done.
# Fold 3 hour 18 train size 10080 done.
# Fold 3 hour 19 train size 10080 done.
# Fold 3 hour 20 train size 10080 done.
# Fold 3 hour 21 train size 10080 done.
# Fold 3 hour 22 train size 10080 done.
# Fold 3 hour 23 train size 10080 done.
# Fold 4 hour 0 train size 10080 done.
# Fold 4 hour 1 train size 10080 done.
# Fold 4 hour 2 train size 10080 done.
# Fold 4 hour 3 train size 10080 done.
# Fold 4 hour 4 train size 10080 done.
# Fold 4 hour 5 train size 10080 done.
# Fold 4 hour 6 train size 10080 done.
# Fold 4 hour 7 train size 10080 done.
# Fold 4 hour 8 train size 10080 done.
# Fold 4 hour 9 train size 10080 done.
# Fold 4 hour 10 train size 10080 done.
# Fold 4 hour 11 train size 10080 done.
# Fold 4 hour 12 train size 10080 done.
# Fold 4 hour 13 train size 10080 done.
# Fold 4 hour 14 train size 10080 done.
# Fold 4 hour 15 train size 10080 done.
# Fold 4 hour 16 train size 10080 done.
# Fold 4 hour 17 train size 10080 done.
# Fold 4 hour 18 train size 10080 done.
# Fold 4 hour 19 train size 10080 done.
# Fold 4 hour 20 train size 10080 done.
# Fold 4 hour 21 train size 10080 done.
# Fold 4 hour 22 train size 10080 done.
# Fold 4 hour 23 train size 10080 done.
# Fold 5 hour 0 train size 10080 done.
# Fold 5 hour 1 train size 10080 done.
# Fold 5 hour 2 train size 10080 done.
# Fold 5 hour 3 train size 10080 done.
# Fold 5 hour 4 train size 10080 done.
# Fold 5 hour 5 train size 10080 done.
# Fold 5 hour 6 train size 10080 done.
# Fold 5 hour 7 train size 10080 done.
# Fold 5 hour 8 train size 10080 done.
# Fold 5 hour 9 train size 10080 done.
# Fold 5 hour 10 train size 10080 done.
# Fold 5 hour 11 train size 10080 done.
# Fold 5 hour 12 train size 10080 done.
# Fold 5 hour 13 train size 10080 done.
# Fold 5 hour 14 train size 10080 done.
# Fold 5 hour 15 train size 10080 done.
# Fold 5 hour 16 train size 10080 done.
# Fold 5 hour 17 train size 10080 done.
# Fold 5 hour 18 train size 10080 done.
# Fold 5 hour 19 train size 10080 done.
# Fold 5 hour 20 train size 10080 done.
# Fold 5 hour 21 train size 10080 done.
# Fold 5 hour 22 train size 10080 done.
# Fold 5 hour 23 train size 10080 done.
# Fold 6 hour 0 train size 10080 done.
# Fold 6 hour 1 train size 10080 done.
# Fold 6 hour 2 train size 10080 done.
# Fold 6 hour 3 train size 10080 done.
# Fold 6 hour 4 train size 10080 done.
# Fold 6 hour 5 train size 10080 done.
# Fold 6 hour 6 train size 10080 done.
# Fold 6 hour 7 train size 10080 done.
# Fold 6 hour 8 train size 10080 done.
# Fold 6 hour 9 train size 10080 done.
# Fold 6 hour 10 train size 10080 done.
# Fold 6 hour 11 train size 10080 done.
# Fold 6 hour 12 train size 10080 done.
# Fold 6 hour 13 train size 10080 done.
# Fold 6 hour 14 train size 10080 done.
# Fold 6 hour 15 train size 10080 done.
# Fold 6 hour 16 train size 10080 done.
# Fold 6 hour 17 train size 10080 done.
# Fold 6 hour 18 train size 10080 done.
# Fold 6 hour 19 train size 10080 done.
# Fold 6 hour 20 train size 10080 done.
# Fold 6 hour 21 train size 10080 done.
# Fold 6 hour 22 train size 10080 done.
# Fold 6 hour 23 train size 10080 done.
# Fold 7 hour 0 train size 10080 done.
# Fold 7 hour 1 train size 10080 done.
# Fold 7 hour 2 train size 10080 done.
# Fold 7 hour 3 train size 10080 done.
# Fold 7 hour 4 train size 10080 done.
# Fold 7 hour 5 train size 10080 done.
# Fold 7 hour 6 train size 10080 done.
# Fold 7 hour 7 train size 10080 done.
# Fold 7 hour 8 train size 10080 done.
# Fold 7 hour 9 train size 10080 done.
# Fold 7 hour 10 train size 10080 done.
# Fold 7 hour 11 train size 10080 done.
# Fold 7 hour 12 train size 10080 done.
# Fold 7 hour 13 train size 10080 done.
# Fold 7 hour 14 train size 10080 done.
# Fold 7 hour 15 train size 10080 done.
# Fold 7 hour 16 train size 10080 done.
# Fold 7 hour 17 train size 10080 done.
# Fold 7 hour 18 train size 10080 done.
# Fold 7 hour 19 train size 10080 done.
# Fold 7 hour 20 train size 10080 done.
# Fold 7 hour 21 train size 10080 done.
# Fold 7 hour 22 train size 10080 done.
# Fold 7 hour 23 train size 10080 done.
# Fold 8 hour 0 train size 10080 done.
# Fold 8 hour 1 train size 10080 done.
# Fold 8 hour 2 train size 10080 done.
# Fold 8 hour 3 train size 10080 done.
# Fold 8 hour 4 train size 10080 done.
# Fold 8 hour 5 train size 10080 done.
# Fold 8 hour 6 train size 10080 done.
# Fold 8 hour 7 train size 10080 done.
# Fold 8 hour 8 train size 10080 done.
# Fold 8 hour 9 train size 10080 done.
# Fold 8 hour 10 train size 10080 done.
# Fold 8 hour 11 train size 10080 done.
# Fold 8 hour 12 train size 10080 done.
# Fold 8 hour 13 train size 10080 done.
# Fold 8 hour 14 train size 10080 done.
# Fold 8 hour 15 train size 10080 done.
# Fold 8 hour 16 train size 10080 done.
# Fold 8 hour 17 train size 10080 done.
# Fold 8 hour 18 train size 10080 done.
# Fold 8 hour 19 train size 10080 done.
# Fold 8 hour 20 train size 10080 done.
# Fold 8 hour 21 train size 10080 done.
# Fold 8 hour 22 train size 10080 done.
# Fold 8 hour 23 train size 10080 done.
# Fold 9 hour 0 train size 10080 done.
# Fold 9 hour 1 train size 10080 done.
# Fold 9 hour 2 train size 10080 done.
# Fold 9 hour 3 train size 10080 done.
# Fold 9 hour 4 train size 10080 done.
# Fold 9 hour 5 train size 10080 done.
# Fold 9 hour 6 train size 10080 done.
# Fold 9 hour 7 train size 10080 done.
# Fold 9 hour 8 train size 10080 done.
# Fold 9 hour 9 train size 10080 done.
# Fold 9 hour 10 train size 10080 done.
# Fold 9 hour 11 train size 10080 done.
# Fold 9 hour 12 train size 10080 done.
# Fold 9 hour 13 train size 10080 done.
# Fold 9 hour 14 train size 10080 done.
# Fold 9 hour 15 train size 10080 done.
# Fold 9 hour 16 train size 10080 done.
# Fold 9 hour 17 train size 10080 done.
# Fold 9 hour 18 train size 10080 done.
# Fold 9 hour 19 train size 10080 done.
# Fold 9 hour 20 train size 10080 done.
# Fold 9 hour 21 train size 10080 done.
# Fold 9 hour 22 train size 10080 done.
# Fold 9 hour 23 train size 10080 done.
# Fold 10 hour 0 train size 10080 done.
# Fold 10 hour 1 train size 10080 done.
# Fold 10 hour 2 train size 10080 done.
# Fold 10 hour 3 train size 10080 done.
# Fold 10 hour 4 train size 10080 done.
# Fold 10 hour 5 train size 10080 done.
# Fold 10 hour 6 train size 10080 done.
# Fold 10 hour 7 train size 10080 done.
# Fold 10 hour 8 train size 10080 done.
# Fold 10 hour 9 train size 10080 done.
# Fold 10 hour 10 train size 10080 done.
# Fold 10 hour 11 train size 10080 done.
# Fold 10 hour 12 train size 10080 done.
# Fold 10 hour 13 train size 10080 done.
# Fold 10 hour 14 train size 10080 done.
# Fold 10 hour 15 train size 10080 done.
# Fold 10 hour 16 train size 10080 done.
# Fold 10 hour 17 train size 10080 done.
# Fold 10 hour 18 train size 10080 done.
# Fold 10 hour 19 train size 10080 done.
# Fold 10 hour 20 train size 10080 done.
# Fold 10 hour 21 train size 10080 done.
# Fold 10 hour 22 train size 10080 done.
# Fold 10 hour 23 train size 10080 done.
# Fold 11 hour 0 train size 10080 done.
# Fold 11 hour 1 train size 10080 done.
# Fold 11 hour 2 train size 10080 done.
# Fold 11 hour 3 train size 10080 done.
# Fold 11 hour 4 train size 10080 done.
# Fold 11 hour 5 train size 10080 done.
# Fold 11 hour 6 train size 10080 done.
# Fold 11 hour 7 train size 10080 done.
# Fold 11 hour 8 train size 10080 done.
# Fold 11 hour 9 train size 10080 done.
# Fold 11 hour 10 train size 10080 done.
# Fold 11 hour 11 train size 10080 done.
# Fold 11 hour 12 train size 10080 done.
# Fold 11 hour 13 train size 10080 done.
# Fold 11 hour 14 train size 10080 done.
# Fold 11 hour 15 train size 10080 done.
# Fold 11 hour 16 train size 10080 done.
# Fold 11 hour 17 train size 10080 done.
# Fold 11 hour 18 train size 10080 done.
# Fold 11 hour 19 train size 10080 done.
# Fold 11 hour 20 train size 10080 done.
# Fold 11 hour 21 train size 10080 done.
# Fold 11 hour 22 train size 10080 done.
# Fold 11 hour 23 train size 10080 done.
# For train size 10080 the rmse is nan MW.
# /tmp/ipykernel_12172/10384856.py:57: RuntimeWarning: invalid value encountered in sqrt
#   rmse = np.sqrt(np.mean((prediction["y_true"] - prediction["y_pred_one_model_per_hour"]**2)))
# Fold 0 hour 0 train size 20160 done.
# Fold 0 hour 1 train size 20160 done.
# Fold 0 hour 2 train size 20160 done.
# Fold 0 hour 3 train size 20160 done.
# Fold 0 hour 4 train size 20160 done.
# Fold 0 hour 5 train size 20160 done.
# Fold 0 hour 6 train size 20160 done.
# Fold 0 hour 7 train size 20160 done.
# Fold 0 hour 8 train size 20160 done.
# Fold 0 hour 9 train size 20160 done.
# Fold 0 hour 10 train size 20160 done.
# Fold 0 hour 11 train size 20160 done.
# Fold 0 hour 12 train size 20160 done.
# Fold 0 hour 13 train size 20160 done.
# Fold 0 hour 14 train size 20160 done.
# Fold 0 hour 15 train size 20160 done.
# Fold 0 hour 16 train size 20160 done.
# Fold 0 hour 17 train size 20160 done.
# Fold 0 hour 18 train size 20160 done.
# Fold 0 hour 19 train size 20160 done.
# Fold 0 hour 20 train size 20160 done.
# Fold 0 hour 21 train size 20160 done.
# Fold 0 hour 22 train size 20160 done.
# Fold 0 hour 23 train size 20160 done.
# Fold 1 hour 0 train size 20160 done.
# Fold 1 hour 1 train size 20160 done.
# Fold 1 hour 2 train size 20160 done.
# Fold 1 hour 3 train size 20160 done.
# Fold 1 hour 4 train size 20160 done.
# Fold 1 hour 5 train size 20160 done.
# Fold 1 hour 6 train size 20160 done.
# Fold 1 hour 7 train size 20160 done.
# Fold 1 hour 8 train size 20160 done.
# Fold 1 hour 9 train size 20160 done.
# Fold 1 hour 10 train size 20160 done.
# Fold 1 hour 11 train size 20160 done.
# Fold 1 hour 12 train size 20160 done.
# Fold 1 hour 13 train size 20160 done.
# Fold 1 hour 14 train size 20160 done.
# Fold 1 hour 15 train size 20160 done.
# Fold 1 hour 16 train size 20160 done.
# Fold 1 hour 17 train size 20160 done.
# Fold 1 hour 18 train size 20160 done.
# Fold 1 hour 19 train size 20160 done.
# Fold 1 hour 20 train size 20160 done.
# Fold 1 hour 21 train size 20160 done.
# Fold 1 hour 22 train size 20160 done.
# Fold 1 hour 23 train size 20160 done.
# Fold 2 hour 0 train size 20160 done.
# Fold 2 hour 1 train size 20160 done.
# Fold 2 hour 2 train size 20160 done.
# Fold 2 hour 3 train size 20160 done.
# Fold 2 hour 4 train size 20160 done.
# Fold 2 hour 5 train size 20160 done.
# Fold 2 hour 6 train size 20160 done.
# Fold 2 hour 7 train size 20160 done.
# Fold 2 hour 8 train size 20160 done.
# Fold 2 hour 9 train size 20160 done.
# Fold 2 hour 10 train size 20160 done.
# Fold 2 hour 11 train size 20160 done.
# Fold 2 hour 12 train size 20160 done.
# Fold 2 hour 13 train size 20160 done.
# Fold 2 hour 14 train size 20160 done.
# Fold 2 hour 15 train size 20160 done.
# Fold 2 hour 16 train size 20160 done.
# Fold 2 hour 17 train size 20160 done.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 42
#      39 y_test_hour_n = y_test.loc[y_test.index.hour == hour]
#      41 model = LinearRegression()
# ---> 42 model.fit(X_train_hour_n, y_train_hour_n)
#      43 prediction_list.append(
#      44     pd.DataFrame(
#      45             {
#    (...)
#      50     )
#      51 )
#      52 print(f"Fold {fold} hour {hour} train size {train_size} done.")
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/linear_model/_base.py:609, in LinearRegression.fit(self, X, y, sample_weight)
#     605 n_jobs_ = self.n_jobs
#     607 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 609 X, y = self._validate_data(
#     610     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     611 )
#     613 has_sw = sample_weight is not None
#     614 if has_sw:
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/base.py:650, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     648         y = check_array(y, input_name="y", **check_y_params)
#     649     else:
# --> 650         X, y = check_X_y(X, y, **check_params)
#     651     out = X, y
#     653 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:1273, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1268         estimator_name = _check_estimator_name(estimator)
#    1269     raise ValueError(
#    1270         f"{estimator_name} requires y to be passed, but the target y is None"
#    1271     )
# -> 1273 X = check_array(
#    1274     X,
#    1275     accept_sparse=accept_sparse,
#    1276     accept_large_sparse=accept_large_sparse,
#    1277     dtype=dtype,
#    1278     order=order,
#    1279     copy=copy,
#    1280     force_all_finite=force_all_finite,
#    1281     ensure_2d=ensure_2d,
#    1282     allow_nd=allow_nd,
#    1283     ensure_min_samples=ensure_min_samples,
#    1284     ensure_min_features=ensure_min_features,
#    1285     estimator=estimator,
#    1286     input_name="X",
#    1287 )
#    1289 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1291 check_consistent_length(X, y)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:878, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     872         warnings.warn(
#     873             "pandas.DataFrame with sparse columns found."
#     874             "It will be converted to a dense numpy array."
#     875         )
#     877 dtypes_orig = list(array.dtypes)
# --> 878 pandas_requires_conversion = any(
#     879     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     880 )
#     881 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
#     882     dtype_orig = np.result_type(*dtypes_orig)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:879, in <genexpr>(.0)
#     872         warnings.warn(
#     873             "pandas.DataFrame with sparse columns found."
#     874             "It will be converted to a dense numpy array."
#     875         )
#     877 dtypes_orig = list(array.dtypes)
#     878 pandas_requires_conversion = any(
# --> 879     _pandas_dtype_needs_early_conversion(i) for i in dtypes_orig
#     880 )
#     881 if all(isinstance(dtype_iter, np.dtype) for dtype_iter in dtypes_orig):
#     882     dtype_orig = np.result_type(*dtypes_orig)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/sklearn/utils/validation.py:701, in _pandas_dtype_needs_early_conversion(pd_dtype)
#     698 except ImportError:
#     699     return False
# --> 701 if isinstance(pd_dtype, SparseDtype) or not is_extension_array_dtype(pd_dtype):
#     702     # Sparse arrays will be converted later in `check_array`
#     703     # Only handle extension arrays for integer and floats
#     704     return False
#     705 elif is_float_dtype(pd_dtype):
#     706     # Float ndarrays can normally support nans. They need to be converted
#     707     # first to map pd.NA to np.nan
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/pandas/core/dtypes/common.py:1277, in is_extension_array_dtype(arr_or_dtype)
#    1271     """
#    1272     Analogue to is_extension_array_dtype but excluding DatetimeTZDtype.
#    1273     """
#    1274     return isinstance(dtype, ExtensionDtype) and not dtype._supports_2d
# -> 1277 def is_extension_array_dtype(arr_or_dtype) -> bool:
#    1278     """
#    1279     Check if an object is a pandas extension array type.
#    1280
#    (...)
#    1320     False
#    1321     """
#    1322     dtype = getattr(arr_or_dtype, "dtype", arr_or_dtype)
#
# File ~/.cache/pypoetry/virtualenvs/simplify-deployment-2FnGvFJr-py3.12/lib/python3.12/site-packages/debugpy/_vendored/pydevd/_pydevd_bundle/pydevd_trace_dispatch_regular.py:326, in ThreadTracer.__call__(self, frame, event, arg)
#     323         self._args = args
#     324 # ENDIF
# --> 326     def __call__(self, frame, event, arg):
#     327         ''' This is the callback used when we enter some context in the debugger.
#     328
#     329         We also decorate the thread we are in with info about the debugging.
#    (...)
#     337             This is the global debugger (this method should actually be added as a method to it).
#     338         '''
#     339         # IFDEF CYTHON
#     340         # cdef str filename;
#     341         # cdef str base;
#    (...)
#     350         # DEBUG = 'code_to_debug' in frame.f_code.co_filename
#     351         # if DEBUG: print('ENTER: trace_dispatch: %s %s %s %s' % (frame.f_code.co_filename, frame.f_lineno, event, frame.f_code.co_name))
#
# KeyboardInterrupt:

# %%
prediction = pd.concat(
    prediction_list,
    axis = 0,
)
prediction = prediction.sort_index(ascending = True)
prediction.to_parquet("/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/one_model_per_hour_24_times_more_train.parquet")

# %%
prediction

# %%
X_train

# %%
y_train

# %%
pd.read_parquet("/home/thomas/repos/simplify_deployment/data/data_science/50_gen_s1/one_model_per_hour.parquet")

# %%
fig = px.line(X_train, x = X_train.index, y = ["hour_sin", "hour_cos"])
fig.show()
